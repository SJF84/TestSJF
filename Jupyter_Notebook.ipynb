# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Silvia Joao-Feistner** <br>
#     Silvia Joao-Feistner - Senior Product Manager

# %% [markdown]
# *I'm interested in data science because it opens up a whole new world of how we see the world. In the course of digitalization and the creation of ever larger amounts of data, data science enables us to "master" them, to gain important insights and build on them.*

# %% [markdown]
# ### Result of a simple addition

# %%
2+3
# Out:
# 5

# %% [markdown]
# | header | header | header | header |
# |----|----|----|----|
# | - text | 1. text | text | text |
# | - text | 2. text | text | text |
# | - text | 3. text | text | text |
#
#
#
#
# __[Link to google.com](https://www.google.de/)__
#
# * A
# * B
# * C
# * D
#
# 1. E
# 2. F
# 3. G
# 4. H
#
# ~strike text~
#
# ![Bild1.jpg](attachment:5f341027-205f-4080-908b-70a9d65d32dd.jpg)
